# %% [markdown]
# # Basics of Python

# %%
#Hello World

# %%
"""
#Hello World

"""
# Out:
# '\n#Hello World \n\n'

# %% [markdown]
# # Identifiers(Variables)

# %%
# Variables are case Sensitive
a=2

# %%
print(a)
# Out:
# 2

# %%
A=12

# %%
print(a)
# Out:
# 2

# %%
print(A)
# Out:
# 12

# %%
# Keywords can not used as a variable name

# %%
fo=2.8

# %%
print(fo)
# Out:
# 2.8

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
as="ABC"

# as is a keyword
# Out:
#   File "C:\Users\20356119\AppData\Local\Temp/ipykernel_6876/4117142647.py", line 1
#     as="ABC"
#     ^
# SyntaxError: invalid syntax

# %%
# Special Charters

# %%
ab123=23

# %%
123ab=450
# Out:
#   File "C:\Users\20356119\AppData\Local\Temp/ipykernel_6876/437983499.py", line 1
#     123ab=450
#        ^
# SyntaxError: invalid syntax

# %%
ab_=10

# %%
print(ab_)
# Out:
# 10

# %%
# Variable can start with _

# %%
_ab=12

# %%
@ab=12
# Out:
#   File "<ipython-input-25-fd1e75ad5906>", line 1
#     @ab=12
#        ^
# SyntaxError: invalid syntax

# %%
ab=25

# %%
a_$=25
# Out:
#   File "<ipython-input-29-399cd3954a55>", line 1
#     a_$=25
#       ^
# SyntaxError: invalid syntax

# %%
_123="xyz"

# %%
123_="abc"
# Out:
#   File "<ipython-input-31-7baaa442b46c>", line 1
#     123_="abc"
#        ^
# SyntaxError: invalid token

# %%
_123a=5

# %% [markdown]
# # Literals
# 1. Numbers
# 2. Strings
# 3. Lists
# 4. Tuples
# 5. Sets
# 6. Dictionary

# %% [markdown]
# ## 1 Numbers
#
#
# 1.   int
# 2.   float
# 3.   Complex

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Integer

# %%
x=10
y=-100
z=120

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(x)
# Out:
# 10

# %%
print(x,y,z)
# Out:
# 10 -100 120

# %%
print("val of x=",x)
# Out:
# val of x= 10

# %%
# Add of 2 int

# %%
x=5
y=10
z=x+y

# %%
print("x=",x)
print("y=",y)
print("z=",z)
# Out:
# x= 5
# y= 10
# z= 15

# %% [markdown]
# # Float

# %%
x=3.14

# %%
print(x)
# Out:
# 3.14

# %%
print(type(x))
# Out:
# <class 'float'>

# %% [markdown]
# ## Complex

# %%
z=3+4j

# %%
print(z)
# Out:
# (3+4j)

# %%
print(type(z))
# Out:
# <class 'complex'>

# %% [markdown]
# # 2 Strings

# %%
x="Welcome"

# %%
print(x)
# Out:
# Welcome

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
y='Welcome'

# %%
print(y)
# Out:
# Welcome

# %%
x = "Python"
y = "is"
z = "awesome"
print(x, y, z)
# Out:
# Python is awesome

# %%
z=""" Welcome"""
print(z)
# Out:
#  Welcome

# %%
p=''' Welcome'''

# %%
print(p)
# Out:
#  Welcome

# %%
y="Welcome to Python programming"

# %%
print(y)
# Out:
# Welcome to Python programming

# %%
y="Welcome to
Python programming"
# Out:
#   File "<ipython-input-60-02cb21d100b8>", line 1
#     y="Welcome to
#                    ^
# SyntaxError: EOL while scanning string literal

# %%
y='Welcome to
Python programming'
# Out:
#   File "<ipython-input-65-f3811f2f7f3e>", line 1
#     y='Welcome to
#                    ^
# SyntaxError: EOL while scanning string literal

# %%
y="""Welcome to
Python programming"""

# %%
print(y)
# Out:
# Welcome to
# Python programming

# %%
# " "  and '' are same

#"""    """   and ''' '''  are same

# %%
print(type(y))
# Out:
# <class 'str'>

# %%
y='''Welcome to
Python programming'''

# %%
print(y)
# Out:
# Welcome to
# Python programming

# %%
x="Welcome"

# %%
print(x[0])
# Out:
# W

# %%
print(x[0:3])
# Out:
# Wel

# %%
x="Welcome"
y="\tLNT"

# %%
print(x+y)
# Out:
# Welcome	LNT

# %% [markdown]
# ### String Functions

# %%
a="Hello"

# %%
a
# Out:
# 'Hello'

# %%
len(a)
# Out:
# 5

# %%
a.upper()
# Out:
# 'HELLO'

# %%
a.capitalize()
# Out:
# 'Hello'

# %% [markdown]
# # Type casting

# %%
# Converting one data type to another

# %%
x=2.5

# %%
print(type(x))
# Out:
# <class 'float'>

# %%
y=int(x)

# %%
print(y)
# Out:
# 2

# %%
y="10"
z=10

# %%
print(type(y))
# Out:
# <class 'str'>

# %%
print(type(z))
# Out:
# <class 'int'>

# %%
# COnvert y to int
#String to int

# %%
y="10"
p=int(y)

# %%
print(y,p)
# Out:
# 10 10

# %%
print(type(y), type(p))
# Out:
# <class 'str'> <class 'int'>

# %% [markdown]
# x=10
# Conver x to Complex no
#
# x=3.25
# convert to int
#
# Display the original values and Converted values
#
# Also display their types

# %%
x=10
print(x)
print(type(x))
# Out:
# 10
# <class 'int'>

# %%
p=complex(x)
print(p)
print(type(p))
# Out:
# (10+0j)
# <class 'complex'>

# %%
print(p)
# Out:
# (10+0j)

# %%
p=3.0059
a=int(p)
print(a)
print(type(a))
# Out:
# 3
# <class 'int'>

# %% [markdown]
# # Input from User

# %%
x=10

# %%
x=x+5

# %%
print(x)
# Out:
# 15

# %%
x=3.14
print(x)
# Out:
# 3.14

# %%
# Variable can store diffrent values and diffrent data types

# %%
x=20

# %%
x=x+15

# %%
print(x)
# Out:
# 35

# %%
input("Enter a no")
# Out:
# Enter a no12
# '12'

# %%
a=input("Enter first no:\t")
# Out:
# Enter first no:	10

# %%
print(a)
# Out:
# 10

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
# Addition of 2 int no
a=input("Enter first no:")
b=input("Enter second no:")
c=a+b
print("Add=",c)
# Out:
# Enter first no:10
# Enter second no:20
# Add= 1020

# %%
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
# type casting
a=input("Enter first no:")
b=input("Enter second no:")
a=int(a)
b=int(b)
c=a+b
print("Add=",c)
# Out:
# Enter first no:10
# Enter second no:20
# Add= 30

# %%
a=int(input("Enter first no:"))
b=int(input("Enter second no:"))

c=a+b
print("Add=",c)
print(type(a))
print(type(b))
print(type(c))
# Out:
# Enter first no:5
# Enter second no:4
# Add= 9
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
#Perform Multiplication of 2 Userdefined Float no

# %% [markdown]
# x=float(input("Enter x \t"))
# y=float(input("Enter y \n"))
# z=x*y
# print(z)

# %% [markdown]
# ### Multiple input in one statement

# %%
phy,chem,maths=input("Enter Marks of Phy, Chem and Maths").split("/")
# Out:
# Enter Marks of Phy, Chem and Maths40/55/80

# %%
print("Physics Marks:",phy)
print("Chemistry Marks:",chem)
print("Physics Marks:",maths)
# Out:
# Physics Marks: 40
# Chemistry Marks: 55
# Physics Marks: 80

# %%
type(phy)
# Out:
# str

# %%
phy=int(phy)
chem=int(chem)
maths=int(maths)

# %%
print("Physics Marks:",phy)
print("Chemistry Marks:",chem)
print("Physics Marks:",maths)
# Out:
# Physics Marks: 40
# Chemistry Marks: 55
# Physics Marks: 80

# %%
type(phy)
# Out:
# int

# %% [markdown]
# # Bollean

# %%
c= True
print(c)
print(type(c))
# Out:
# True
# <class 'bool'>

# %%
d= False

# %%
a=5
b=10

# %%
a>b
# Out:
# False

# %%
a!=5
# Out:
# False

# %%
a!=10
# Out:
# True

# %% [markdown]
# # None

# %%
s= None

# %%
print(s)
# Out:
# None

# %%
print(type(s))
# Out:
# <class 'NoneType'>

# %% [markdown]
# # Operators
#
#
# 1.   Assignment
# 2.   Arithmetic
# 3.    Logical
# 4.    Identity Operators

# %%
#Assignment
x=10
x=x*10
print(x)
# Out:
# 100

# %%
#Arithmetic   + - * /

# %%
x=5
y=2
print(x+y)
print(x-y)
print(x*y)
# Out:
# 7
# 3
# 10

# %%
# Division
print(x/y)
# Out:
# 2.5

# %%
print(x//y)
# Out:
# 2

# %%
# Modulus %
x=5
y=2
print(x%y)
# Out:
# 1

# %% [markdown]
# ### Arithmatic Calculator Example

# %%
num1 = int(input("Enter the first number "))
num2 = int(input("Enter another number "))
sum = num1 + num2
diff = num1 - num2
mult = num1 * num2
div = num1 / num2
mean = (num1+num2)/2
print("Sum of {0} and {1} is {2}".format(num1, num2,sum))
print("Diff of {0} and {1} is {2}".format(num1, num2,diff))
print("Prod of {0} and {1} is {2}".format(num1, num2,mult))
print("Div of {0} and {1} is {2}".format(num1, num2,div))
print("Mean of {0} and {1} is {2}".format(num1, num2,mean))
# Out:
# Enter the first number 10
# Enter another number 20
# Sum of 10 and 20 is 30
# Diff of 10 and 20 is -10
# Prod of 10 and 20 is 200
# Div of 10 and 20 is 0.5
# Mean of 10 and 20 is 15.0

# %% [markdown]
# # Logical Operators

# %%
x=5
y=10

# %%
print(x>y)
# Out:
# False

# %%
print(y>x)
# Out:
# True

# %%
x!=y
# Out:
# True

# %%
x==y
# Out:
# False

# %% [markdown]
# Bitwise Operators

# %% [markdown]
# decimal  Binary
# 5   =    0101=   0 * 2^3 +1* 2^2 + 0* 2^1  + 1 * 2^0
# 4   =    0100
# 5 | 4    0101    = 5

# %% [markdown]
# ## Bitwise Operators

# %%
x=5
y=4
z= x & y

# %%
print(z)
# Out:
# 4

# %%
z= x | y
print(z)
# Out:
# 5

# %%
z= !x

# %%
z
# Out:
# ['/bin/bash: x: command not found']
